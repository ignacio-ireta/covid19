# %%
import pandas as pd

# %%
peru = pd.read_csv(r"PATH", sep=";")  # Because for some reason ";" in a csv is better

# %%
peru['FECHA_CORTE'] = pd.to_datetime(peru['FECHA_CORTE'], format='%Y%m%d').dt.strftime('%Y-%m-%d')  # Reformat their dates

# %%
peru['FECHA_RESULTADO'] = pd.to_datetime(peru['FECHA_CORTE'], format='mixed').dt.strftime('%Y-%m-%d')

# %%
peru.to_csv(r"PATH",sep=',')  # Save with generic corrections

# %%
peru
# Out:
#         FECHA_CORTE DEPARTAMENTO  PROVINCIA              DISTRITO METODODX  \
# 0        2024-12-03       TUMBES     TUMBES                TUMBES       AG
# 1        2024-12-03         LIMA       LIMA           JESUS MARIA       AG
# 2        2024-12-03   SAN MARTIN  MOYOBAMBA             MOYOBAMBA       AG
# 3        2024-12-03     AREQUIPA   CAYLLOMA             COPORAQUE       AG
# 4        2024-12-03         LIMA       LIMA           JESUS MARIA       AG
# ...             ...          ...        ...                   ...      ...
# 4585355  2024-12-03         LIMA       LIMA           JESUS MARIA       AG
# 4585356  2024-12-03         LIMA       LIMA           EL AGUSTINO       AG
# 4585357  2024-12-03         LIMA       LIMA                   ATE       AG
# 4585358  2024-12-03         LIMA       LIMA  SAN MARTIN DE PORRES       AG
# 4585359  2024-12-03         LIMA       LIMA            CARABAYLLO       AG
#
#          EDAD       SEXO FECHA_RESULTADO    UBIGEO  id_persona
# ...
